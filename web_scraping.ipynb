# %% [markdown]
# # Task 1
#
# ---
#
# ## Web scraping and analysis
#
# This Jupyter notebook includes some code to get you started with web scraping. We will use a package called `BeautifulSoup` to collect the data from the web. Once you've collected your data and saved it into a local `.csv` file you should start with your analysis.
#
# .

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
base_url = "https://www.airlinequality.com/airline-reviews/kenya-airways/"
pages = 10
page_size = 200

reviews = []


# for i in range(1, pages + 1):
for i in range(1, pages + 1):

    print(f"Scraping page {i}")

    # Create URL to collect links from paginated data
    url = f"{base_url}/page/{i}/?sortby=post_date%3ADesc&pagesize={page_size}"

    # Collect HTML data from this page
    response = requests.get(url)

    # Parse content
    content = response.content
    parsed_content = BeautifulSoup(content, 'html.parser')
    for para in parsed_content.find_all("div", {"class": "text_content"}):
        reviews.append(para.get_text())

    print(f"   ---> {len(reviews)} total reviews")
# Out:
# Scraping page 1
#    ---> 200 total reviews
# Scraping page 2
#    ---> 400 total reviews
# Scraping page 3
#    ---> 456 total reviews
# Scraping page 4
#    ---> 456 total reviews
# Scraping page 5
#    ---> 456 total reviews
# Scraping page 6
#    ---> 456 total reviews
# Scraping page 7
#    ---> 456 total reviews
# Scraping page 8
#    ---> 456 total reviews
# Scraping page 9
#    ---> 456 total reviews
# Scraping page 10
#    ---> 456 total reviews

# %%
df = pd.DataFrame()
df["reviews"] = reviews
df.head()
# Out:
#                                              reviews
# 0  Not Verified |  I frequently fly to Kinshasa a...
# 1  ✅ Trip Verified |  05 Oct 2023 London-Nairobi....
# 2  Not Verified |  My recent experience with Keny...
# 3  Not Verified |  Delayed and cancelled flights ...
# 4  ✅ Trip Verified |  Kigali to Amsterdam via Nai...

# %%
df.to_csv("KA_reviews.csv")

# %% [markdown]
# Congratulations! Now you have your dataset for this task! The loops above collected 1000 reviews by iterating through the paginated pages on the website. However, if you want to collect more data, try increasing the number of pages!
#
#  The next thing that you should do is clean this data to remove any unnecessary text from each of the rows. For example, "✅ Trip Verified" can be removed from each row if it exists, as it's not relevant to what we want to investigate.

# %% [markdown]
# ## Data Cleaning

# %%
import pandas as pd

csv_path = "KA_reviews.csv"
df1 = pd.read_csv(csv_path)
df1.reset_index(drop=True, inplace=True)

print(df1['reviews'])
# Out:
# 0      Not Verified |  I frequently fly to Kinshasa a...
# 1      ✅ Trip Verified |  05 Oct 2023 London-Nairobi....
# 2      Not Verified |  My recent experience with Keny...
# 3      Not Verified |  Delayed and cancelled flights ...
# 4      ✅ Trip Verified |  Kigali to Amsterdam via Nai...
#                              ...
# 451    JNB-NBO-JNB. This trip showed both the good an...
# 452    Nairobi-London. Lounge in Nairobi was small an...
# 453    Nairobi-London. As me and my wife are both whe...
# 454    LUN-LLW in Economy. Adequate for a 1 hr trip. ...
# 455    I fly Kenya very often (almost once every 2 we...
# Name: reviews, Length: 456, dtype: object

# %%
df1.info()
df1.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 456 entries, 0 to 455
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  456 non-null    int64
#  1   reviews     456 non-null    object
# dtypes: int64(1), object(1)
# memory usage: 7.2+ KB
#        Unnamed: 0
# count   456.00000
# mean    227.50000
# std     131.78012
# min       0.00000
# 25%     113.75000
# 50%     227.50000
# 75%     341.25000
# max     455.00000

# %%
df1['reviews'] = df1['reviews'].str.strip()
df1['reviews']=df1['reviews'].str.lstrip('✅ Trip Verified |')
df1['reviews']=df1['reviews'].str.lstrip('Not Verified |')
df1['reviews']= df1['reviews'].str.lower()
print(df1)
# Out:
#      Unnamed: 0                                            reviews
# 0             0  i frequently fly to kinshasa and chose this ti...
# 1             1  05 oct 2023 london-nairobi. we are a couple an...
# 2             2  my recent experience with kenya airways was in...
# 3             3  delayed and cancelled flights so arrived 10 ho...
# 4             4  kigali to amsterdam via nairobi 4th feb. 2024....
# ..          ...                                                ...
# 451         451  jnb-nbo-jnb. this trip showed both the good an...
# 452         452  airobi-london. lounge in nairobi was small and...
# 453         453  airobi-london. as me and my wife are both whee...
# 454         454  lun-llw in economy. adequate for a 1 hr trip. ...
# 455         455  i fly kenya very often (almost once every 2 we...
#
# [456 rows x 2 columns]

# %%
#remove punctuation
df1['reviews'] = df1['reviews'].str.replace('[^\w\s]','')
print(df1['reviews'])
# Out:
# 0      i frequently fly to kinshasa and chose this ti...
# 1      05 oct 2023 londonnairobi we are a couple and ...
# 2      my recent experience with kenya airways was in...
# 3      delayed and cancelled flights so arrived 10 ho...
# 4      kigali to amsterdam via nairobi 4th feb 2024 t...
#                              ...
# 451    jnbnbojnb this trip showed both the good and a...
# 452    airobilondon lounge in nairobi was small and f...
# 453    airobilondon as me and my wife are both wheelc...
# 454    lunllw in economy adequate for a 1 hr trip fa ...
# 455    i fly kenya very often almost once every 2 wee...
# Name: reviews, Length: 456, dtype: object
# <ipython-input-9-05b35ac04ac2>:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df1['reviews'] = df1['reviews'].str.replace('[^\w\s]','')

# %%
del df1['Unnamed: 0']
df1.head()
# Out:
#                                              reviews
# 0  i frequently fly to kinshasa and chose this ti...
# 1  05 oct 2023 londonnairobi we are a couple and ...
# 2  my recent experience with kenya airways was in...
# 3  delayed and cancelled flights so arrived 10 ho...
# 4  kigali to amsterdam via nairobi 4th feb 2024 t...

# %%
df1.to_csv("KA_reviews_cleaning.csv")
